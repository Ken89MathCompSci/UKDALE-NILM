# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/20-May-2026-base_models-advanced-lnn-pinn-basic-lnn-cross-house-fine-tuning-Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python fine_tuning_dataset_scripts/test_pinn_twosided_lnn_finetune.py
# Out:
# Device: cuda
# Dataset: /content/UKDALE-NILM/fine_tuning_dataset_scripts/../fine_tuning_dataset
#
# Loading splits...
#   pretrain    : 28,800 rows  [2014-11-09 00:00:00  to  2014-12-07 23:59:54]
#   validation  : 14,400 rows  [2014-12-07 00:00:00  to  2014-12-07 23:59:54]
#   finetune    :  1,200 rows  [2014-08-24 00:00:00  to  2014-08-24 01:59:54]
#   test        : 13,200 rows  [2014-08-24 02:00:00  to  2014-08-24 23:59:54]
#
#   pretrain  X=(5740, 100, 1)  Y=(5740, 4)
#   val       X=(2860, 100, 1)  Y=(2860, 4)
#   finetune  X=(220, 100, 1)   Y=(220, 4)
#   test      X=(2620, 100, 1)   Y=(2620, 4)
#
# Model parameters: 4,804
#
# === Phase 1: Pretrain (House 1) ===
#   Two-sided physics: ε_over=50.0W  α_floor=0.15  λ_under=0.5  λ_phys=0.01
#   Epoch   1/80  train=0.01795 (mse=0.01795 over=57.19105 under=32.78138)  val=0.29042 (mse=0.00796 over=7.37146 under=41.74900)  avgF1=0.2032  lr=1.00e-03  [warmup]
# ...

# %%
# !python fine_tuning_dataset_scripts/test_gru_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# GRU — dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Parameters: 397,313
#   Phase 1: Pretrain
#     Ep   1  train=0.01166  val=0.01465  F1=0.1396  P=0.0750  R=1.0000  MAE=57.19  SAE=41.7158  TP=178  FP=2195  TN=487  FN=0  time=1.2s
# Model successfully saved to: models/gru_finetune_20260519_141037/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.01160  val=0.01348  F1=0.1172  P=0.0622  R=1.0000  MAE=120.21  SAE=106.3067  TP=178  FP=2682  TN=0  FN=0  time=0.7s
# Model successfully saved to: models/gru_finetune_20260519_141037/dishwasher/pretrain_dishwasher_best.pth
#     Ep   3  train=0.01143  val=0.01394  F1=0.1172  P=0.0622  R=1.0000  MAE=113.63  SAE=100.1126  TP=178  FP=2682  TN=0  FN=0  time=0.8s
# ...

# %%
# !python fine_tuning_dataset_scripts/test_lnn_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# LNN -- dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Parameters: 4,353
#   Phase 1: Pretrain
#     Ep   1  train=0.01082  val=0.00958  F1=0.1172  P=0.0622  R=1.0000  MAE=105.63  SAE=94.7481  TP=178  FP=2682  TN=0  FN=0  time=14.8s
# Model successfully saved to: models/lnn_finetune_20260519_141405/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.00946  val=0.01052  F1=0.2187  P=0.1231  R=0.9775  MAE=88.27  SAE=73.5924  TP=174  FP=1239  TN=1443  FN=4  time=14.4s
#     Ep   3  train=0.00974  val=0.01019  F1=0.1106  P=0.0588  R=0.9157  MAE=70.40  SAE=55.8326  TP=163  FP=2607  TN=75  FN=15  time=14.5s
#     Ep   4  train=0.00924  val=0.00907  F1=0.1753  P=0.1233  R=0.3034  MAE=92.12  SAE=72.7162  TP=54  FP=384  TN=2298  FN=124  time=14.5s
# ...

# %%
# !python fine_tuning_dataset_scripts/test_lstm_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# LSTM -- dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Parameters: 50,497
#   Phase 1: Pretrain
#     Ep   1  train=0.01177  val=0.01357  F1=0.1430  P=0.0770  R=1.0000  MAE=65.86  SAE=50.1097  TP=178  FP=2133  TN=549  FN=0  time=1.0s
# Model successfully saved to: models/lstm_finetune_20260519_201218/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.01095  val=0.01390  F1=0.1172  P=0.0622  R=1.0000  MAE=62.64  SAE=47.1337  TP=178  FP=2682  TN=0  FN=0  time=0.6s
#     Ep   3  train=0.01050  val=0.01391  F1=0.1172  P=0.0622  R=1.0000  MAE=82.92  SAE=68.2375  TP=178  FP=2682  TN=0  FN=0  time=0.6s
#     Ep   4  train=0.01051  val=0.01250  F1=0.1172  P=0.0622  R=1.0000  MAE=90.42  SAE=75.9201  TP=178  FP=2682  TN=0  FN=0  time=0.6s
# ...

# %%
# !python fine_tuning_dataset_scripts/test_resnet_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# ResNet — dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Parameters: 392,833
#   Phase 1: Pretrain
#     Ep   1  train=0.05152  val=0.07132  F1=0.1974  P=0.1324  R=0.3876  MAE=271.65  SAE=225.1049  TP=69  FP=452  TN=2230  FN=109  time=3.0s
# Model successfully saved to: models/resnet_finetune_20260519_152258/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.00831  val=0.01145  F1=0.2535  P=0.1957  R=0.3596  MAE=75.84  SAE=40.3323  TP=64  FP=263  TN=2419  FN=114  time=1.8s
# Model successfully saved to: models/resnet_finetune_20260519_152258/dishwasher/pretrain_dishwasher_best.pth
#     Ep   3  train=0.00666  val=0.02257  F1=0.0929  P=0.0500  R=0.6573  MAE=92.19  SAE=64.8873  TP=117  FP=2225  TN=457  FN=61  time=1.8s
# ...

# %%
# !python fine_tuning_dataset_scripts/test_tcn_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# TCN -- dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Parameters: 31,169
#   Phase 1: Pretrain
#     Ep   1  train=0.00911  val=0.00843  F1=0.2417  P=0.1851  R=0.3483  MAE=102.67  SAE=79.0851  TP=62  FP=273  TN=2409  FN=116  time=1.2s
# Model successfully saved to: models/tcn_finetune_20260519_153307/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.00729  val=0.00935  F1=0.2561  P=0.2006  R=0.3539  MAE=48.36  SAE=35.2943  TP=63  FP=251  TN=2431  FN=115  time=0.6s
#     Ep   3  train=0.00668  val=0.00698  F1=0.2702  P=0.2206  R=0.3483  MAE=48.08  SAE=34.8641  TP=62  FP=219  TN=2463  FN=116  time=0.6s
# Model successfully saved to: models/tcn_finetune_20260519_153307/dishwasher/pretrain_dishwasher_best.pth
# ...

# %%
# !python fine_tuning_dataset_scripts/test_transformer_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# Transformer — dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Parameters: 595,201
#   Phase 1: Pretrain
#     Ep   1  train=0.14098  val=0.00967  F1=0.1883  P=0.1039  R=1.0000  MAE=107.12  SAE=94.7078  TP=178  FP=1535  TN=1147  FN=0  time=2.4s
# Model successfully saved to: models/transformer_finetune_20260519_153536/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.01103  val=0.01055  F1=0.2304  P=0.2043  R=0.2640  MAE=111.83  SAE=96.0759  TP=47  FP=183  TN=2499  FN=131  time=1.9s
#     Ep   3  train=0.00905  val=0.01276  F1=0.1162  P=0.0618  R=0.9831  MAE=79.04  SAE=65.4345  TP=175  FP=2659  TN=23  FN=3  time=1.9s
#     Ep   4  train=0.00908  val=0.01006  F1=0.1172  P=0.0622  R=1.0000  MAE=115.15  SAE=104.7283  TP=178  FP=2682  TN=0  FN=0  time=1.9s
# ...

# %%
# !python test_pinn_basic_lnn_finetune.py
# Out:
# Device: cuda
# Dataset: fine_tuning_dataset
#
# Loading splits...
#   pretrain    : 28,800 rows  [2014-11-09 00:00:00  to  2014-12-07 23:59:54]
#   validation  : 14,400 rows  [2014-12-07 00:00:00  to  2014-12-07 23:59:54]
#   finetune    :  1,200 rows  [2014-08-24 00:00:00  to  2014-08-24 01:59:54]
#   test        : 13,200 rows  [2014-08-24 02:00:00  to  2014-08-24 23:59:54]
#
#   pretrain  X=(5740, 100, 1)  Y=(5740, 4)
#   val       X=(2860, 100, 1)  Y=(2860, 4)
#   finetune  X=(220, 100, 1)   Y=(220, 4)
#   test      X=(2620, 100, 1)   Y=(2620, 4)
#
# Model parameters: 4,804
#
# === Phase 1: Pretrain (House 1) ===
#   Epoch   1/80  train=0.01114 (mse=0.01114 phys=15.85128)  val=0.12719 (mse=0.00876)  avgF1=0.2355  lr=1.00e-03  [warmup]
#   Epoch   2/80  train=0.00841 (mse=0.00841 phys=7.67782)  val=0.02740 (mse=0.00728)  avgF1=0.3128  lr=1.00e-03  [warmup]
#   Epoch   3/80  train=0.00778 (mse=0.00778 phys=4.96749)  val=0.01664 (mse=0.00673)  avgF1=0.2673  lr=1.00e-03  [warmup]
# ...

# %%
# !python fine_tuning_dataset_scripts/test_advanced_lnn_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# Advanced LNN -- dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Parameters: 29,441
#   Phase 1: Pretrain
#     Ep   1  train=0.01129  val=0.01233  F1=0.2117  P=0.1206  R=0.8652  MAE=66.44  SAE=50.0344  TP=154  FP=1123  TN=1559  FN=24  time=51.8s
# Model successfully saved to: models/advanced_lnn_finetune_20260519_155535/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.00981  val=0.00888  F1=0.2054  P=0.1162  R=0.8820  MAE=60.38  SAE=48.7756  TP=157  FP=1194  TN=1488  FN=21  time=51.1s
# Model successfully saved to: models/advanced_lnn_finetune_20260519_155535/dishwasher/pretrain_dishwasher_best.pth
#     Ep   3  train=0.00914  val=0.01234  F1=0.2253  P=0.1907  R=0.2753  MAE=41.99  SAE=27.5326  TP=49  FP=208  TN=2474  FN=129  time=51.3s
# ...
