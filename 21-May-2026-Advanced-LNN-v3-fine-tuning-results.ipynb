# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/21-May-2026-Advanced-LNN-v3-fine-tuning-results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python fine_tuning_dataset_scripts/test_advanced_lnn_v3_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# Advanced LNN v3 — dishwasher
# ...
#
# Appliance: dishwasher  |  device: cpu
#   Parameters: 37,633
#   Phase 1: Pretrain
#     Ep   1  train=0.01051  val=0.00995  F1=0.2100  P=0.1174  R=0.9944  MAE=81.55  SAE=67.4347  TP=177  FP=1331  TN=1351  FN=1  time=33.7s
# Model successfully saved to: models/advanced_lnn_v3_finetune_20260520_162616/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.00966  val=0.01038  F1=0.1801  P=0.1253  R=0.3202  MAE=82.78  SAE=65.0911  TP=57  FP=398  TN=2284  FN=121  time=34.2s
#     Ep   3  train=0.00925  val=0.00894  F1=0.1336  P=0.0798  R=0.4101  MAE=64.78  SAE=51.6905  TP=73  FP=842  TN=1840  FN=105  time=32.7s
# Model successfully saved to: models/advanced_lnn_v3_finetune_20260520_162616/dishwasher/pretrain_dishwasher_best.pth
# ...

# %%
# !python fine_tuning_dataset_scripts/test_advanced_lnn_v2_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
# Device: cpu  hidden=64  n_heads=2  dt=0.1
# TCN: 3 layers, hidden=32, dilations=1/2/4
# Focal: gamma=2.0, alpha=0.35
# Loss weights: power=1.0  event=0.5  trans=0.1  cons=0.05
#
# Class balance (fraction ON per appliance):
#   App                      pretrain        val   finetune       test
#   dishwasher                 0.0645     0.0622     0.0000     0.0668
#   fridge                     0.4357     0.4192     0.4591     0.4229
#   microwave                  0.0115     0.0077     1.0000     1.0000
#   washing_machine            0.0857     0.0657     1.0000     1.0000
#   Train: (5740, 100, 1)  Val: (2860, 100, 1)  FT: (220, 100, 1)  Test: (2620, 100, 1)
#   Parameters: 46,851
#
# ...
# Phase 1: Supervised Pretrain  (80 epochs max)
# ...
