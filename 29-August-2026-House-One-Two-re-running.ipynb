# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/29-August-2026-House-One-Two-re-running.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python APR-new-scripts-House2/test_tcn_apr_new_house2_dataset_v2.py
# Out:
# Testing Gated TCN v2 on APR-new-House2-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-07-14 23:59:54+00:00  (432,000 rows)
#   Val: 2013-07-15 00:00:00+00:00 to 2013-07-21 23:59:54+00:00  (100,800 rows)
#   Test: 2013-07-22 00:00:00+00:00 to 2013-07-28 23:59:54+00:00  (100,800 rows)
#
#   Adaptive thresholds (train-locked, replaces v1's hand-picked 10/20/30/10W):
#     dishwasher       21.0W
#     fridge           30.0W
#     microwave        45.0W
#     washing_machine  21.0W
#
# ...
# Testing Gated TCN on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=21.0W)
#   Gate target: on=2.7%  pos_weight=36.1  thr_scaled=0.0099
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting Gated TCN training for dishwasher...
# ...

# %%
# !python APR-new-scripts-House2/test_transformer_apr_new_house2_dataset_v2.py
# Out:
# Testing Gated Transformer v2 on APR-new-House2-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-07-14 23:59:54+00:00  (432,000 rows)
#   Val: 2013-07-15 00:00:00+00:00 to 2013-07-21 23:59:54+00:00  (100,800 rows)
#   Test: 2013-07-22 00:00:00+00:00 to 2013-07-28 23:59:54+00:00  (100,800 rows)
#
#   Adaptive thresholds (train-locked, replaces v1's hand-picked 10/20/30/10W):
#     dishwasher       21.0W
#     fridge           30.0W
#     microwave        45.0W
#     washing_machine  21.0W
#
# ...
# Testing Gated Transformer on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=21.0W)
#   Gate target: on=2.7%  pos_weight=36.1  thr_scaled=0.0099
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting Gated Transformer training for dishwasher...
# ...

# %%
# !python APR-new-scripts-House2/test_resnet_apr_new_house2_dataset_v2.py
# Out:
# Testing Gated ResNet v2 on APR-new-House2-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-07-14 23:59:54+00:00  (432,000 rows)
#   Val: 2013-07-15 00:00:00+00:00 to 2013-07-21 23:59:54+00:00  (100,800 rows)
#   Test: 2013-07-22 00:00:00+00:00 to 2013-07-28 23:59:54+00:00  (100,800 rows)
#
#   Adaptive thresholds (train-locked, replaces v1's hand-picked 10/20/30/10W):
#     dishwasher       21.0W
#     fridge           30.0W
#     microwave        45.0W
#     washing_machine  21.0W
#
# ...
# Testing Gated ResNet on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=21.0W)
#   Gate target: on=2.7%  pos_weight=36.1  thr_scaled=0.0099
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting Gated ResNet training for dishwasher...
# ...
