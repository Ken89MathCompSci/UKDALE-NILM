# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/6-September-house-5-second-run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python APR-new-scripts-House5/nilm_sfra_svm_house5.py
# Out:
# Loading APR-new-House5-dataset from '/content/UKDALE-NILM/APR-new-scripts-House5/../APR-new-House5-dataset' ...
#   train : 432,000 rows  2014-08-04 -> 2014-09-02
#   val   : 100,800 rows  2014-09-03 -> 2014-09-09
#   test  : 100,800 rows  2014-09-10 -> 2014-09-16
#
# Adaptive thresholds (train-locked):
#   dishwasher         77.0 W
#   fridge             10.0 W
#   microwave          68.0 W
#   washing_machine    34.0 W
#
# Computing features ...
#   Train: 432,000 samples -> using 20,000 for SVM
#   Test : 100,800 samples
#
#   [dishwasher]
#     Train ON%=2.0%  Test ON%=2.4%
#     class_weight: raw=48.0  clamped=10.0
#   [fridge]
#     Train ON%=36.8%  Test ON%=37.2%
#     class_weight: raw=1.7  clamped=1.7
#   [microwave]
#     Train ON%=0.1%  Test ON%=0.2%
#     class_weight: raw=908.1  clamped=10.0
#   [washing_machine]
#     Train ON%=2.3%  Test ON%=10.6%
#     class_weight: raw=42.5  clamped=10.0
#
# ...

# %%
# !python APR-new-scripts-House5/test_gru_apr_new_house5_dataset.py
# Out:
# Testing GRU on APR-new-House5-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House5-dataset
#   Train: 2014-08-04 00:00:00+00:00 to 2014-09-02 23:59:54+00:00  (432,000 rows)
#   Val: 2014-09-03 00:00:00+00:00 to 2014-09-09 23:59:54+00:00  (100,800 rows)
#   Test: 2014-09-10 00:00:00+00:00 to 2014-09-16 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing GRU on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting GRU training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:04<00:00, 557.71it/s, loss=9.54e-6]
# Epoch 1/80, Train Loss: 0.007863, Val Loss: 0.008122, Val MAE: 27.41, Val SAE: 25.66, Val F1: 0.1952, Val Precision: 0.1176, Val Recall: 0.5734
# ...

# %%
# !python APR-new-scripts-House5/test_lnn_apr_new_house5_dataset.py
# Out:
# Testing LiquidNetworkModel on APR-new-House5-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House5-dataset
#   Train: 2014-08-04 00:00:00+00:00 to 2014-09-02 23:59:54+00:00  (432,000 rows)
#   Val: 2014-09-03 00:00:00+00:00 to 2014-09-09 23:59:54+00:00  (100,800 rows)
#   Test: 2014-09-10 00:00:00+00:00 to 2014-09-16 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing LiquidNetworkModel on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting LiquidNetworkModel training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:53<00:00, 50.85it/s, loss=0.00117]
# Epoch 1/80, Train Loss: 0.007954, Val Loss: 0.009721, Val MAE: 56.17, Val SAE: 53.06, Val F1: 0.4843, Val Precision: 0.4139, Val Recall: 0.5835
# ...

# %%
# !python APR-new-scripts-House5/test_lstm_apr_new_house5_dataset.py
# Out:
# Testing LSTM on APR-new-House5-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House5-dataset
#   Train: 2014-08-04 00:00:00+00:00 to 2014-09-02 23:59:54+00:00  (432,000 rows)
#   Val: 2014-09-03 00:00:00+00:00 to 2014-09-09 23:59:54+00:00  (100,800 rows)
#   Test: 2014-09-10 00:00:00+00:00 to 2014-09-16 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing LSTM on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting LSTM training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:07<00:00, 354.20it/s, loss=2.09e-5]
# Epoch 1/80, Train Loss: 0.008327, Val Loss: 0.009776, Val MAE: 38.56, Val SAE: 35.50, Val F1: 0.2058, Val Precision: 0.1190, Val Recall: 0.7589
# ...

# %%
# !python APR-new-scripts-House5/test_resnet_apr_new_house5_dataset_v2.py
# Out:
# Testing Gated ResNet v2 on APR-new-House5-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House5-dataset
#   Train: 2014-08-04 00:00:00+00:00 to 2014-09-02 23:59:54+00:00  (432,000 rows)
#   Val: 2014-09-03 00:00:00+00:00 to 2014-09-09 23:59:54+00:00  (100,800 rows)
#   Test: 2014-09-10 00:00:00+00:00 to 2014-09-16 23:59:54+00:00  (100,800 rows)
#
#   Adaptive thresholds (train-locked, replaces v1's hand-picked 10/20/30/10W):
#     dishwasher       77.0W
#     fridge           10.0W
#     microwave        68.0W
#     washing_machine  34.0W
#
# ...
# Testing Gated ResNet on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=77.0W)
#   Gate target: on=2.1%  pos_weight=45.9  thr_scaled=0.0451
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting Gated ResNet training for dishwasher...
# ...

# %%
# !python APR-new-scripts-House5/test_tcn_apr_new_house5_dataset_v2.py
# Out:
# Testing Gated TCN v2 on APR-new-House5-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House5-dataset
#   Train: 2014-08-04 00:00:00+00:00 to 2014-09-02 23:59:54+00:00  (432,000 rows)
#   Val: 2014-09-03 00:00:00+00:00 to 2014-09-09 23:59:54+00:00  (100,800 rows)
#   Test: 2014-09-10 00:00:00+00:00 to 2014-09-16 23:59:54+00:00  (100,800 rows)
#
#   Adaptive thresholds (train-locked, replaces v1's hand-picked 10/20/30/10W):
#     dishwasher       77.0W
#     fridge           10.0W
#     microwave        68.0W
#     washing_machine  34.0W
#
# ...
# Testing Gated TCN on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=77.0W)
#   Gate target: on=2.1%  pos_weight=45.9  thr_scaled=0.0451
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting Gated TCN training for dishwasher...
# ...

# %%
# !python APR-new-scripts-House5/combined_pinn_lnn_apr_new_house5_dataset.py
# Out:
# Loading APR-new-House5-dataset CSV data from '/content/UKDALE-NILM/APR-new-scripts-House5/../APR-new-House5-dataset' ...
#   train : 432,000 rows  2014-08-04 -> 2014-09-02
#   val   : 100,800 rows  2014-09-03 -> 2014-09-09
#   test  : 100,800 rows  2014-09-10 -> 2014-09-16
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Model: CombinedPINNAdvancedLNN  (gated power = gate x power)
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           77.0     77.0     77.0
#   fridge               10.0     10.0     10.0
#   microwave            68.0     68.0     68.0
#   washing_machine      34.0     34.0     34.0
#
# Creating sequences ...
#   Train : (43171, 299, 8) -> (43171, 299, 4)  (12,908,129 predictions)
#   Val   : (10051, 299, 8) -> (10051, 299, 4)
#   Test  : (337, 299, 8) -> (337, 299, 4)  [non-overlapping]
#
#   Agg Z-score: mean=712.3 W  std=551.6 W
#
# ...
