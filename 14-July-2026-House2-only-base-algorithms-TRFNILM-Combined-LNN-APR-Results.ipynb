# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/14-July-2026-House2-only-base-algorithms-TRFNILM-Combined-LNN-APR-Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python APR-new-scripts-House2/test_gru_apr_new_house2_dataset.py
# Out:
# Testing GRU on APR-new-House2-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-07-14 23:59:54+00:00  (432,000 rows)
#   Val: 2013-07-15 00:00:00+00:00 to 2013-07-21 23:59:54+00:00  (100,800 rows)
#   Test: 2013-07-22 00:00:00+00:00 to 2013-07-28 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing GRU on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting GRU training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:04<00:00, 578.58it/s, loss=0.000404]
# Epoch 1/80, Train Loss: 0.005586, Val Loss: 0.001721, Val MAE: 39.73, Val SAE: 31.94, Val F1: 0.0425, Val Precision: 0.0217, Val Recall: 1.0000
# ...

# %%
# !python APR-new-scripts-House2/test_lnn_apr_new_house2_dataset.py
# Out:
# Testing LiquidNetworkModel on APR-new-House2-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-07-14 23:59:54+00:00  (432,000 rows)
#   Val: 2013-07-15 00:00:00+00:00 to 2013-07-21 23:59:54+00:00  (100,800 rows)
#   Test: 2013-07-22 00:00:00+00:00 to 2013-07-28 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing LiquidNetworkModel on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting LiquidNetworkModel training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:52<00:00, 51.09it/s, loss=5.86e-5]
# Epoch 1/80, Train Loss: 0.004815, Val Loss: 0.001741, Val MAE: 22.95, Val SAE: 16.45, Val F1: 0.1512, Val Precision: 0.0827, Val Recall: 0.8817
# ...

# %%
# !python APR-new-scripts-House2/test_lstm_apr_new_house2_dataset.py
# Out:
# Testing LSTM on APR-new-House2-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-07-14 23:59:54+00:00  (432,000 rows)
#   Val: 2013-07-15 00:00:00+00:00 to 2013-07-21 23:59:54+00:00  (100,800 rows)
#   Test: 2013-07-22 00:00:00+00:00 to 2013-07-28 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing LSTM on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting LSTM training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:07<00:00, 350.07it/s, loss=0.000155]
# Epoch 1/80, Train Loss: 0.011143, Val Loss: 0.010862, Val MAE: 102.44, Val SAE: 94.23, Val F1: 0.0419, Val Precision: 0.0214, Val Recall: 1.0000
# ...

# %%
# !python APR-new-scripts-House2/test_resnet_apr_new_house2_dataset.py
# Out:
# Testing ResNet on APR-new-House2-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-07-14 23:59:54+00:00  (432,000 rows)
#   Val: 2013-07-15 00:00:00+00:00 to 2013-07-21 23:59:54+00:00  (100,800 rows)
#   Test: 2013-07-22 00:00:00+00:00 to 2013-07-28 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing ResNet on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting ResNet training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:08<00:00, 325.26it/s, loss=6.51e-5]
# Epoch 1/80, Train Loss: 0.006735, Val Loss: 0.002650, Val MAE: 37.60, Val SAE: 31.90, Val F1: 0.4260, Val Precision: 0.2758, Val Recall: 0.9350
# ...

# %%
# !python APR-new-scripts-House2/test_tcn_apr_new_house2_dataset.py
# Out:
# Testing TCN on APR-new-House2-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-07-14 23:59:54+00:00  (432,000 rows)
#   Val: 2013-07-15 00:00:00+00:00 to 2013-07-21 23:59:54+00:00  (100,800 rows)
#   Test: 2013-07-22 00:00:00+00:00 to 2013-07-28 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing TCN on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting TCN training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:03<00:00, 872.89it/s, loss=1.99e-6]
# Epoch 1/80, Train Loss: 0.003326, Val Loss: 0.001331, Val MAE: 16.68, Val SAE: 7.70, Val F1: 0.8407, Val Precision: 0.8034, Val Recall: 0.8817
# ...

# %%
# !python APR-new-scripts-House2/test_transformer_apr_new_house2_dataset.py
# Out:
# Testing Transformer on APR-new-House2-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-07-14 23:59:54+00:00  (432,000 rows)
#   Val: 2013-07-15 00:00:00+00:00 to 2013-07-21 23:59:54+00:00  (100,800 rows)
#   Test: 2013-07-22 00:00:00+00:00 to 2013-07-28 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing Transformer on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting Transformer training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:08<00:00, 303.62it/s, loss=0.000256]
# Epoch 1/80, Train Loss: 0.023745, Val Loss: 0.001134, Val MAE: 45.10, Val SAE: 42.44, Val F1: 0.0419, Val Precision: 0.0214, Val Recall: 1.0000
# ...

# %%
# !python APR-new-scripts-House2/test_rf_apr_new_house2_dataset.py
# Out:
# Loading data from: /content/UKDALE-NILM/APR-new-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-07-14 23:59:54+00:00  (432,000 rows)
#   Val: 2013-07-15 00:00:00+00:00 to 2013-07-21 23:59:54+00:00  (100,800 rows)
#   Test: 2013-07-22 00:00:00+00:00 to 2013-07-28 23:59:54+00:00  (100,800 rows)
#
# ...
# Training RandomForestRegressor on dishwasher
# ...
#
# Building windowed features for dishwasher...
#   Train: (86380, 10)  ON=2.86%
#   Val:   (20140, 10)  ON=2.14%
#   Test:  (20140, 10)  ON=3.07%
# Fitting RandomForestRegressor (300 trees) for dishwasher...
#   Val  -- F1=0.5514  P=0.3914  R=0.9327  MAE=2.88  SAE=1.9015
#   Test -- F1=0.5484  P=0.4041  R=0.8528  MAE=4.15  SAE=3.0837  TP=527  TN=18,745  FP=777  FN=91
#
# ...
# Training RandomForestRegressor on fridge
# ...
#
# Building windowed features for fridge...
#   Train: (86380, 10)  ON=74.43%
#   Val:   (20140, 10)  ON=73.71%
#   Test:  (20140, 10)  ON=82.71%
# Fitting RandomForestRegressor (300 trees) for fridge...
# ...

# %%
# !python APR-new-scripts-House2/combined_pinn_lnn_apr_new_house2_dataset.py
# Out:
# Loading APR-new-House2-dataset CSV data from '/content/UKDALE-NILM/APR-new-scripts-House2/../APR-new-House2-dataset' ...
#   train : 432,000 rows  2013-06-15 -> 2013-07-14
#   val   : 100,800 rows  2013-07-15 -> 2013-07-21
#   test  : 100,800 rows  2013-07-22 -> 2013-07-28
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Model: CombinedPINNAdvancedLNN  (gated power = gate x power)
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           21.0     21.0     21.0
#   fridge               30.0     30.0     30.0
#   microwave            45.0     45.0     45.0
#   washing_machine      21.0     23.0     21.0
#
# Creating sequences ...
#   Train : (43171, 299, 8) -> (43171, 299, 4)  (12,908,129 predictions)
#   Val   : (10051, 299, 8) -> (10051, 299, 4)
#   Test  : (337, 299, 8) -> (337, 299, 4)  [non-overlapping]
#
#   Agg Z-score: mean=275.6 W  std=408.0 W
#
# ...

# %%
# !python APR-new-scripts-House2/test_pinn_lnn_apr_new_house2_dataset.py
# Out:
# Loading data from: /content/UKDALE-NILM/APR-new-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-07-14 23:59:54+00:00  (432,000 rows)
#   Val: 2013-07-15 00:00:00+00:00 to 2013-07-21 23:59:54+00:00  (100,800 rows)
#   Test: 2013-07-22 00:00:00+00:00 to 2013-07-28 23:59:54+00:00  (100,800 rows)
# Using device: cuda
# lambda_phys=0.01  epsilon=50.0 W  hidden=64  dt=0.1
# Thresholds: {'dishwasher': 10.0, 'fridge': 20.0, 'microwave': 30.0, 'washing_machine': 10.0}
# Train ON-rate:  {'dishwasher': 2.86, 'fridge': 43.88, 'microwave': 0.43, 'washing_machine': 1.44}
# MSE weights:    {'dishwasher': 1.0, 'fridge': 0.2, 'microwave': 1.971, 'washing_machine': 1.072}
# Train: (86380, 100, 1) -> (86380, 4)
# Val:   (20140, 100, 1) -> (20140, 4)
# Test:  (20140, 100, 1) -> (20140, 4)
# Model parameters: 9,028
# Starting PINN-LNN training (all appliances simultaneously)...
# ...
