# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/3-August-2026-2nd-Run-House1-House2-combined-lnn-results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python APR-new-scripts/combined_pinn_lnn_apr_new_house1_dataset_v2.py
# Out:
# Loading APR-new-House1-dataset CSV data from '/content/UKDALE-NILM/APR-new-scripts/../APR-new-House1-dataset' ...
#   train : 432,000 rows  2014-09-08 -> 2014-10-07
#   val   : 100,800 rows  2014-10-08 -> 2014-10-14
#   test  : 100,800 rows  2014-10-15 -> 2014-10-21
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Model: CombinedPINNAdvancedLNN v2  (gated power = gate x power)
#
# Fixes active:
#   FIX 1 -- eval thresholds locked to train split for all splits
#   FIX 2 -- checkpoint = best min-per-appliance val F1 (not val MSE)
#   FIX 3 -- lambda ramp: 10 epochs linear warmup after epoch 20
#
#   Eval thresholds (W)  [all splits evaluated against TRAIN thresholds]:
#   Appliance           Train   Val(raw)   Test(raw)  note
#   dishwasher           21.0       21.0        21.0  ok (Δtest=+0.0)
#   fridge               10.0       10.0        10.0  ok (Δtest=+0.0)
# ...

# %%
# !python APR-new-scripts-House2/combined_pinn_lnn_apr_new_house2_dataset_v2.py
# Out:
# Loading APR-new-House2-dataset CSV data from '/content/UKDALE-NILM/APR-new-scripts-House2/../APR-new-House2-dataset' ...
#   train : 432,000 rows  2013-06-15 -> 2013-07-14
#   val   : 100,800 rows  2013-07-15 -> 2013-07-21
#   test  : 100,800 rows  2013-07-22 -> 2013-07-28
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Model: CombinedPINNAdvancedLNN v2  (gated power = gate x power)
#
# Fixes active:
#   FIX 1 -- N/A for House 2 (cycling threshold exception never fires)
#   FIX 2 -- pos_weight upper clamp raised 50 -> 250 (microwave ~249:1 imbalance)
#   FIX 3 -- lambda ramp: 10 epochs linear warmup after epoch 20
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           21.0     21.0     21.0
#   fridge               30.0     30.0     30.0
#   microwave            45.0     45.0     45.0
#   washing_machine      21.0     23.0     21.0
#
# ...
