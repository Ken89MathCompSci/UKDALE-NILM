# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/19-May-2026-base_models-pinn-basic-lnn-cross-house-fine-tuning-troubleshoot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python fine_tuning_dataset_scripts/test_advanced_lnn_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# Advanced LNN -- dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Phase 1: Pretrain
#     Ep   1  train=0.01069  val=0.01072  F1=0.1360  MAE=75.36
# Model successfully saved to: models/advanced_lnn_finetune_20260518_090011/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.00996  val=0.01187  F1=0.1172  MAE=86.66
#     Ep   3  train=0.00913  val=0.00963  F1=0.1172  MAE=62.08
# Model successfully saved to: models/advanced_lnn_finetune_20260518_090011/dishwasher/pretrain_dishwasher_best.pth
#     Ep   4  train=0.00872  val=0.00964  F1=0.1838  MAE=50.74
#     Ep   5  train=0.00863  val=0.00853  F1=0.2063  MAE=50.82
# Model successfully saved to: models/advanced_lnn_finetune_20260518_090011/dishwasher/pretrain_dishwasher_best.pth
#     Ep   6  train=0.00875  val=0.01004  F1=0.2312  MAE=55.32
# ...

# %%
# !python fine_tuning_dataset_scripts/test_gru_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# GRU — dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Phase 1: Pretrain
#     Ep   1  train=0.01169  val=0.01354  F1=0.2234  MAE=60.37
# Model successfully saved to: models/gru_finetune_20260518_125529/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.01130  val=0.01412  F1=0.1388  MAE=63.19
#     Ep   3  train=0.01136  val=0.01473  F1=0.1934  MAE=52.29
#     Ep   4  train=0.01102  val=0.01180  F1=0.1382  MAE=78.98
# Model successfully saved to: models/gru_finetune_20260518_125529/dishwasher/pretrain_dishwasher_best.pth
#     Ep   5  train=0.00994  val=0.01006  F1=0.1172  MAE=88.24
# Model successfully saved to: models/gru_finetune_20260518_125529/dishwasher/pretrain_dishwasher_best.pth
#     Ep   6  train=0.00920  val=0.00866  F1=0.2760  MAE=88.91
# ...

# %%
# !python fine_tuning_dataset_scripts/test_lnn_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# LNN -- dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Phase 1: Pretrain
#     Ep   1  train=0.01271  val=0.01001  F1=0.1544  MAE=82.44
# Model successfully saved to: models/lnn_finetune_20260518_125924/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.00983  val=0.00930  F1=0.1824  MAE=109.43
# Model successfully saved to: models/lnn_finetune_20260518_125924/dishwasher/pretrain_dishwasher_best.pth
#     Ep   3  train=0.00949  val=0.00875  F1=0.1739  MAE=77.60
# Model successfully saved to: models/lnn_finetune_20260518_125924/dishwasher/pretrain_dishwasher_best.pth
#     Ep   4  train=0.00904  val=0.00954  F1=0.1172  MAE=71.26
#     Ep   5  train=0.00908  val=0.00982  F1=0.1396  MAE=56.53
#     Ep   6  train=0.00877  val=0.00913  F1=0.1929  MAE=53.58
# ...

# %%
# !python fine_tuning_dataset_scripts/test_lstm__finetune.py
# Out:
# python3: can't open file '/content/UKDALE-NILM/fine_tuning_dataset_scripts/test_lstm__finetune.py': [Errno 2] No such file or directory

# %%
# !python fine_tuning_dataset_scripts/test_resnet_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# ResNet — dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Phase 1: Pretrain
#     Ep   1  train=0.04218  val=0.01790  F1=0.1191  MAE=236.30
# Model successfully saved to: models/resnet_finetune_20260518_141614/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.00885  val=0.00162  F1=0.1235  MAE=50.64
# Model successfully saved to: models/resnet_finetune_20260518_141614/dishwasher/pretrain_dishwasher_best.pth
#     Ep   3  train=0.00529  val=0.01847  F1=0.1168  MAE=177.29
#     Ep   4  train=0.00565  val=0.00904  F1=0.1177  MAE=188.51
#     Ep   5  train=0.00478  val=0.01401  F1=0.2631  MAE=73.06
#     Ep   6  train=0.00403  val=0.00262  F1=0.1966  MAE=62.93
#     Ep   7  train=0.00159  val=0.00991  F1=0.1221  MAE=56.67
#     Ep   8  train=0.00124  val=0.00055  F1=0.1217  MAE=34.20
# ...

# %%
# !python fine_tuning_dataset_scripts/test_tcn_lnn_finetune.py
# Out:
# python3: can't open file '/content/UKDALE-NILM/fine_tuning_dataset_scripts/test_tcn_lnn_finetune.py': [Errno 2] No such file or directory

# %%
# !python fine_tuning_dataset_scripts/test_transformer_finetune.py
# Out:
# Loading fine_tuning_dataset splits...
#   pretrain    : 28,800 rows
#   validation  : 14,400 rows
#   finetune    :  1,200 rows
#   test        : 13,200 rows
#
# ...
# Transformer — dishwasher
# ...
#
# Appliance: dishwasher  |  device: cuda
#   Phase 1: Pretrain
#     Ep   1  train=0.28266  val=0.01360  F1=0.2196  MAE=164.85
# Model successfully saved to: models/transformer_finetune_20260518_142705/dishwasher/pretrain_dishwasher_best.pth
#     Ep   2  train=0.01103  val=0.01443  F1=0.2603  MAE=168.94
#     Ep   3  train=0.01045  val=0.00981  F1=0.2170  MAE=116.01
# Model successfully saved to: models/transformer_finetune_20260518_142705/dishwasher/pretrain_dishwasher_best.pth
#     Ep   4  train=0.01019  val=0.01559  F1=0.2611  MAE=221.12
#     Ep   5  train=0.00934  val=0.01108  F1=0.1173  MAE=132.28
#     Ep   6  train=0.00839  val=0.01096  F1=0.1172  MAE=74.49
#     Ep   7  train=0.00919  val=0.01167  F1=0.2645  MAE=88.13
#     Ep   8  train=0.00685  val=0.00620  F1=0.1950  MAE=51.81
# ...

# %%
# !python test_pinn_basic_lnn_finetune.py
# Out:
# Device: cuda
# Dataset: fine_tuning_dataset
#
# Loading splits...
#   pretrain    : 28,800 rows  [2014-11-09 00:00:00  to  2014-12-07 23:59:54]
#   validation  : 14,400 rows  [2014-12-07 00:00:00  to  2014-12-07 23:59:54]
#   finetune    :  1,200 rows  [2014-08-24 00:00:00  to  2014-08-24 01:59:54]
#   test        : 13,200 rows  [2014-08-24 02:00:00  to  2014-08-24 23:59:54]
#
#   pretrain  X=(5740, 100, 1)  Y=(5740, 4)
#   val       X=(2860, 100, 1)  Y=(2860, 4)
#   finetune  X=(220, 100, 1)   Y=(220, 4)
#   test      X=(2620, 100, 1)   Y=(2620, 4)
#
# Model parameters: 4,804
#
# === Phase 1: Pretrain (House 1) ===
#   Epoch   1/80  train=0.01288 (mse=0.01288 phys=27.05511)  val=0.18604 (mse=0.00935)  avgF1=0.3048  lr=1.00e-03  [warmup]
#   Epoch   2/80  train=0.00846 (mse=0.00846 phys=12.04347)  val=0.02480 (mse=0.00788)  avgF1=0.3436  lr=1.00e-03  [warmup]
#   Epoch   3/80  train=0.00823 (mse=0.00823 phys=6.90199)  val=0.02102 (mse=0.00823)  avgF1=0.3573  lr=1.00e-03  [warmup]
# ...
