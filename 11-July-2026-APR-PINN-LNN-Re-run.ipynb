# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/11-July-2026-APR-PINN-LNN-Re-run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python APR-new-scripts/test_pinn_advanced_lnn_apr_new_house1_dataset.py
# Out:
# Loading data from: /content/UKDALE-NILM/APR-new-House1-dataset
#   Train: 2014-09-08 00:00:00+00:00 to 2014-10-07 23:59:54+00:00  (432,000 rows)
#   Val: 2014-10-08 00:00:00+00:00 to 2014-10-14 23:59:54+00:00  (100,800 rows)
#   Test: 2014-10-15 00:00:00+00:00 to 2014-10-21 23:59:54+00:00  (100,800 rows)
# Using device: cuda
# lambda_phys=0.01  epsilon=50.0 W  hidden=64  num_layers=2  dt=0.1
# Thresholds: {'dishwasher': 10.0, 'fridge': 10.0, 'microwave': 10.0, 'washing_machine': 10.0}
# Train: (86360, 200, 1) -> (86360, 4)
# Val:   (20120, 200, 1) -> (20120, 4)
# Test:  (20120, 200, 1) -> (20120, 4)
# Model parameters: 29,892
# Starting PINN-AdvancedLNN training (all appliances simultaneously)...
#   Epoch   1/80  train=0.01367 (mse=0.00424 phys=0.94373)  val=0.00361 (mse=0.00353 phys=0.00783)  avgF1=0.2103  avgMAE=56.78  lr=1.00e-03
#     dishwasher            F1=0.0560  P=0.0288  R=1.0000  MAE=57.08  SAE=55.9915
# ...
