# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/9-July-2026-Pinn-LNN-Results-APR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python APR-new-scripts/test_pinn_lnn_apr_new_house1_dataset.py # new
# Out:
# Loading data from: /content/UKDALE-NILM/APR-new-House1-dataset
#   Train: 2014-09-08 00:00:00+00:00 to 2014-10-07 23:59:54+00:00  (432,000 rows)
#   Val: 2014-10-08 00:00:00+00:00 to 2014-10-14 23:59:54+00:00  (100,800 rows)
#   Test: 2014-10-15 00:00:00+00:00 to 2014-10-21 23:59:54+00:00  (100,800 rows)
# Using device: cuda
# lambda_phys=0.01  epsilon=50.0 W  hidden=64  dt=0.1
# Thresholds: {'dishwasher': 10.0, 'fridge': 10.0, 'microwave': 10.0, 'washing_machine': 10.0}
# Train ON-rate:  {'dishwasher': 2.86, 'fridge': 49.37, 'microwave': 1.4, 'washing_machine': 6.45}
# MSE weights:    {'dishwasher': 1.198, 'fridge': 0.289, 'microwave': 1.715, 'washing_machine': 0.798}
# Train: (86380, 100, 1) -> (86380, 4)
# Val:   (20140, 100, 1) -> (20140, 4)
# Test:  (20140, 100, 1) -> (20140, 4)
# Model parameters: 9,028
# Starting PINN-LNN training (all appliances simultaneously)...
# ...

# %%
# !python APR-new-scripts/test_pinn_lnn_apr_new_house1_dataset.py
# Out:
# Loading data from: /content/UKDALE-NILM/APR-new-House1-dataset
#   Train: 2014-09-08 00:00:00+00:00 to 2014-10-07 23:59:54+00:00  (432,000 rows)
#   Val: 2014-10-08 00:00:00+00:00 to 2014-10-14 23:59:54+00:00  (100,800 rows)
#   Test: 2014-10-15 00:00:00+00:00 to 2014-10-21 23:59:54+00:00  (100,800 rows)
# Using device: cuda
# lambda_phys=0.01  epsilon=50.0 W  hidden=64  dt=0.1
# Thresholds: {'dishwasher': 10.0, 'fridge': 10.0, 'microwave': 10.0, 'washing_machine': 10.0}
# Train: (86380, 100, 1) -> (86380, 4)
# Val:   (20140, 100, 1) -> (20140, 4)
# Test:  (20140, 100, 1) -> (20140, 4)
# Model parameters: 9,028
# Starting PINN-LNN training (all appliances simultaneously)...
#   Epoch   1/80  train=0.00350 (mse=0.00350 phys=12.84056)  val=0.06797 (mse=0.00314 phys=6.48253)  avgF1=0.2371  avgMAE=73.69  lr=1.00e-03
#     dishwasher            F1=0.1484  P=0.0970  R=0.3155  MAE=72.74  SAE=61.4917
#     fridge                F1=0.6431  P=0.4750  R=0.9954  MAE=46.18  SAE=24.9460
# ...

# %%
# !python APR-new-scripts/test_pinn_basic_lnn_h1h2_dataset.py
# Out:
# Loading data from: /content/UKDALE-NILM/APR-House1-House2-dataset
#   Train: 2013-06-15 00:00:00+00:00 to 2013-06-15 23:59:54+00:00  (14,400 rows)  cols=['main', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#   Val: 2013-09-01 00:00:00+00:00 to 2013-09-01 23:59:54+00:00  (14,400 rows)  cols=['main', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#   Test: 2014-11-09 00:00:00+00:00 to 2014-11-09 23:59:54+00:00  (14,400 rows)  cols=['main', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
# Using device: cuda
# lambda_phys=0.01  epsilon=50.0 W  hidden=64  dt=0.1
# Thresholds: {'dishwasher': 10.0, 'fridge': 15.0, 'microwave': 10.0, 'washing_machine': 10.0}
# Train: (2860, 100, 1) -> (2860, 4)
# Val:   (2860, 100, 1) -> (2860, 4)
# Test:  (2860, 100, 1) -> (2860, 4)
# Model parameters: 4,804
# Starting PINN-BasicLNN training (all appliances simultaneously)...
# ...
