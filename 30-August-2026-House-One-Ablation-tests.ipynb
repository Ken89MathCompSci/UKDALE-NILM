# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/30-August-2026-House-One-Ablation-tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python APR-new-scripts/ablations/ablation1_no_gate.py
# Out:
# Loading APR-new-House1-dataset CSV data from '/content/UKDALE-NILM/APR-new-scripts/ablations/../../APR-new-House1-dataset' ...
#   train : 432,000 rows  2014-09-08 -> 2014-10-07
#   val   : 100,800 rows  2014-10-08 -> 2014-10-14
#   test  : 100,800 rows  2014-10-15 -> 2014-10-21
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cpu  |  WIN=299  hidden=64  dt=0.1
# Model: UngatedPINNLNN  [ABLATION 1: no gate -- power = sigmoid(power_logit)]
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           21.0     21.0     21.0
#   fridge               10.0     10.0     10.0
#   microwave            21.0     21.0     21.0
#   washing_machine      23.0     23.0     23.0
#
# Creating sequences ...
#   Train : (43171, 299, 8) -> (43171, 299, 4)  (12,908,129 predictions)
#   Val   : (10051, 299, 8) -> (10051, 299, 4)
#   Test  : (337, 299, 8) -> (337, 299, 4)  [non-overlapping]
#
# ...

# %%
# !python APR-new-scripts/ablations/ablation2_unidirectional_lnn.py
# Out:
# Loading APR-new-House1-dataset CSV data from '/content/UKDALE-NILM/APR-new-scripts/ablations/../../APR-new-House1-dataset' ...
#   train : 432,000 rows  2014-09-08 -> 2014-10-07
#   val   : 100,800 rows  2014-10-08 -> 2014-10-14
#   test  : 100,800 rows  2014-10-15 -> 2014-10-21
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cpu  |  WIN=299  hidden=64  dt=0.1
# Model: UnidirectionalPINNLNN  [ABLATION 2: no backward LiquidCell pass]
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           21.0     21.0     21.0
#   fridge               10.0     10.0     10.0
#   microwave            21.0     21.0     21.0
#   washing_machine      23.0     23.0     23.0
#
# Creating sequences ...
#   Train : (43171, 299, 8) -> (43171, 299, 4)  (12,908,129 predictions)
#   Val   : (10051, 299, 8) -> (10051, 299, 4)
#   Test  : (337, 299, 8) -> (337, 299, 4)  [non-overlapping]
#
# ...

# %%
# !python APR-new-scripts/ablations/ablation3_gru_instead_of_liquidcell.py
# Out:
# Loading APR-new-House1-dataset CSV data from '/content/UKDALE-NILM/APR-new-scripts/ablations/../../APR-new-House1-dataset' ...
#   train : 432,000 rows  2014-09-08 -> 2014-10-07
#   val   : 100,800 rows  2014-10-08 -> 2014-10-14
#   test  : 100,800 rows  2014-10-15 -> 2014-10-21
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cpu  |  WIN=299  hidden=64
# Model: CombinedPINNGRU  [ABLATION 3: LiquidCell -> nn.GRUCell]
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           21.0     21.0     21.0
#   fridge               10.0     10.0     10.0
#   microwave            21.0     21.0     21.0
#   washing_machine      23.0     23.0     23.0
#
# Creating sequences ...
#   Train : (43171, 299, 8) -> (43171, 299, 4)  (12,908,129 predictions)
#   Val   : (10051, 299, 8) -> (10051, 299, 4)
#   Test  : (337, 299, 8) -> (337, 299, 4)  [non-overlapping]
#
#   Agg Z-score: mean=404.1 W  std=505.1 W
#
# ...

# %%
# !python APR-new-scripts/ablations/ablation4_raw_feature_only.py
# Out:
# Loading APR-new-House1-dataset CSV data from '/content/UKDALE-NILM/APR-new-scripts/ablations/../../APR-new-House1-dataset' ...
#   train : 432,000 rows  2014-09-08 -> 2014-10-07
#   val   : 100,800 rows  2014-10-08 -> 2014-10-14
#   test  : 100,800 rows  2014-10-15 -> 2014-10-21
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Model: CombinedPINNAdvancedLNN  [ABLATION 4: raw feature only, 1 input channel]
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           21.0     21.0     21.0
#   fridge               10.0     10.0     10.0
#   microwave            21.0     21.0     21.0
#   washing_machine      23.0     23.0     23.0
#
# Creating sequences ...
#   Train : (43171, 299, 1) -> (43171, 299, 4)  (12,908,129 predictions)
#   Val   : (10051, 299, 1) -> (10051, 299, 4)
#   Test  : (337, 299, 1) -> (337, 299, 4)  [non-overlapping]
# ...
