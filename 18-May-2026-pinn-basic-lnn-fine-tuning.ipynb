# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/18-May-2026-pinn-basic-lnn-fine-tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python test_pinn_basic_lnn_finetune.py
# Out:
# Device: cuda
# Dataset: fine_tuning_dataset
#
# Loading splits...
#   pretrain    : 28,800 rows  [2014-11-09 00:00:00  to  2014-12-07 23:59:54]
#   validation  : 14,400 rows  [2014-12-07 00:00:00  to  2014-12-07 23:59:54]
#   finetune    :  1,200 rows  [2014-08-24 00:00:00  to  2014-08-24 01:59:54]
#   test        : 13,200 rows  [2014-08-24 02:00:00  to  2014-08-24 23:59:54]
#
#   pretrain  X=(5740, 100, 1)  Y=(5740, 4)
#   val       X=(2860, 100, 1)  Y=(2860, 4)
#   finetune  X=(220, 100, 1)   Y=(220, 4)
#   test      X=(2620, 100, 1)   Y=(2620, 4)
#
# Model parameters: 4,804
#
# === Phase 1: Pretrain (House 1) ===
#   Epoch   1/80  train=0.01061 (mse=0.01061 phys=9.65145)  val=0.04434 (mse=0.00755)  avgF1=0.3510  lr=1.00e-03  [warmup]
#   Epoch   2/80  train=0.00802 (mse=0.00802 phys=5.89621)  val=0.02079 (mse=0.00715)  avgF1=0.2439  lr=1.00e-03  [warmup]
#   Epoch   3/80  train=0.00808 (mse=0.00808 phys=4.40364)  val=0.03121 (mse=0.00667)  avgF1=0.3432  lr=1.00e-03  [warmup]
# ...

# %%
# !python test_pinn_lnn_ukdale_medium_dataset.py
# Out:
# Loading CSVs from 'medium_dataset/'...
#   train       : 432,000 rows  2014-11-01 -> 2014-11-30
#   validation  : 100,800 rows  2014-12-01 -> 2014-12-07
#   test        : 100,800 rows  2014-08-24 -> 2014-08-30
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
# Using device: cuda
# λ_phys=0.01  ε=50.0 W  hidden=64  dt=0.1
# Min ON  : {'dishwasher': 300, 'fridge': 10, 'microwave': 2, 'washing_machine': 300}
# Min OFF : {'dishwasher': 300, 'fridge': 2, 'microwave': 5, 'washing_machine': 27}
# Train: (86380, 100, 1) -> (86380, 4)
# Val:   (20140, 100, 1) -> (20140, 4)
# Test:  (20140, 100, 1) -> (20140, 4)
# Model parameters: 9,028
# Warmup: MSE+sparsity for 20 epochs, then + physics + BCE.
#
#   [WARMUP] Epoch   1/80  train=0.00318 (mse=0.00313 phys=4.88805)  val=0.01954 (mse=0.00359 phys=1.59581)  avgF1=0.2294  avgMAE=80.06  lr=1.00e-03
#     dishwasher          F1=0.0734  P=0.0381  R=1.0000  MAE=88.28  TP=767  FP=19,373  FN=0
# ...

# %%
# !python analyse_representations_medium.py --model-dir models/pinn_lnn_medium_TIMESTAMP
# Out:
# Device: cuda
#
# Loading and preprocessing data ...
# Loading CSVs from 'medium_dataset/'...
#   train       : 432,000 rows  2014-11-01 -> 2014-11-30
#   validation  : 100,800 rows  2014-12-01 -> 2014-12-07
#   test        : 100,800 rows  2014-08-24 -> 2014-08-30
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#   X_tr=(86380, 100, 1)  X_va=(20140, 100, 1)  X_te=(20140, 100, 1)
# ERROR: models/pinn_lnn_medium_TIMESTAMP/best_model.pt not found. Re-run training — best_model.pt is saved automatically.

# %%
# !python test_pinn_lnn_ukdale_long_dataset.py
# Out:
# Loading CSVs from 'long_dataset/'...
#   train       : (2635200, 5)  2014-06-01 → 2014-11-30
#   validation  : (201600, 5)  2014-12-01 → 2014-12-14
#   test        : (201600, 5)  2014-08-24 → 2014-09-06
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  λ_phys=0.01  λ_sparse=0.005  ε=50.0W  hidden=64  dt=0.1
#
# Eval thresholds  (cycling fix): {'dishwasher': 21.0, 'fridge': 10.0, 'microwave': 21.0, 'washing_machine': 23.0}
# Event thresholds (BCE targets) : {'dishwasher': 21.0, 'fridge': 104.0, 'microwave': 21.0, 'washing_machine': 23.0}
#
# Train: (527021, 100, 1) → (527021, 4)
# Val:   (40301, 100, 1) → (40301, 4)
# Test:  (40301, 100, 1) → (40301, 4)
# Model parameters: 9,028
# Starting training...
#   Epoch   1/80  train=0.00219 (mse=0.00215 phys=2.93317)  val=0.00598 (mse=0.00255 phys=0.34367)  avgF1=0.3358  avgMAE=55.82  lr=1.00e-03
#     dishwasher              F1=0.2548  P=0.1996  R=0.3520  MAE=81.04  TP=415  FP=1664  FN=764
# ...

# %%
# !python preprocess_hf.py

# %%
# !python test_pinn_lnn_ukdale_old_dataset_v4_spectral.py
# Out:
# Loading UKDALE data from: /content/UKDALE-NILM/dataset
#   train rows= 14400  2014-11-09 -> 2014-11-09
#   val   rows= 14400  2014-12-07 -> 2014-12-07
#   test  rows= 14400  2014-08-24 -> 2014-08-24
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  |  WIN=100  STRIDE=5  hidden=64  dt=0.1
# Spectral pre-processing: Hanning window + FFT  N_MODES=16  N_IN=17
# seq2seq=True  stitched_metrics=True  lambda_phys=0.01  epsilon=50.0 W  BCE=disabled
#
#   Adaptive thresholds (W):
#   Appliance               Train      Val     Test
#   dishwasher               21.0     44.0     77.0
#   fridge                   10.0     10.0     10.0
#   microwave                21.0     21.0     68.0
#   washing_machine          23.0     23.0     35.0
#
#   Train : (2861, 100, 17) -> (2861, 100, 4)
#   Val   : (2861, 100, 17) -> (2861, 100, 4)
#   Test  : (144, 100, 17) -> (144, 100, 4)  [non-overlapping]
#
# ...

# %%
# !python test_pinn_lnn_ukdale_old_dataset_v4.py
# Out:
# Loading UKDALE data from: /content/UKDALE-NILM/dataset
#   train rows= 14400  2014-11-09 -> 2014-11-09
#   val   rows= 14400  2014-12-07 -> 2014-12-07
#   test  rows= 14400  2014-08-24 -> 2014-08-24
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  |  WIN=100  STRIDE=5  hidden=64  dt=0.1
# seq2seq=True  stitched_metrics=True  lambda_phys=0.01  epsilon=50.0 W  BCE=disabled
#
#   Adaptive thresholds (W):
#   Appliance               Train      Val     Test
#   dishwasher               21.0     44.0     77.0
#   fridge                   10.0     10.0     10.0
#   microwave                21.0     21.0     68.0
#   washing_machine          23.0     23.0     35.0
#
#   Train : (2861, 100, 1) -> (2861, 100, 4)
#   Val   : (2861, 100, 1) -> (2861, 100, 4)
#   Test  : (144, 100, 1) -> (144, 100, 4)  [non-overlapping]
#
#   Model parameters: 9,028
#
# ...

# %%
# !python test_pinn_lnn_ukdale_specific_splits_v4.py
# Out:
# Loading UKDALE v4 data from: /content/UKDALE-NILM/new_dataset
# train rows=14400  range=2014-09-11 00:00:00+00:00 -> 2014-09-11 23:59:54+00:00
# val   rows=14400  range=2014-11-09 00:00:00+00:00 -> 2014-11-09 23:59:54+00:00
# test  rows=14400  range=2014-12-19 00:00:00+00:00 -> 2014-12-19 23:59:54+00:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
# Using device: cuda
# seq2seq=True  stitched_metrics=True  lambda_phys=0.01  epsilon=50.0 W
# hidden=64  dt=0.1  BCE=disabled
# Train: (2861, 100, 1) -> (2861, 100, 4)
# Val:   (2861, 100, 1) -> (2861, 100, 4)
# Test:  (2861, 100, 1) -> (2861, 100, 4)
# Model parameters: 9,028
# Starting seq2seq PINN-LNN training...
#   Epoch   1/80  train=1.07226 (mse=0.05742 phys=101.483)  val=0.00576 (mse=0.00478 phys=0.098)  avgF1=0.3111  avgMAE=70.79  lr=1.00e-03
#     dish washer     F1=0.2528  P=0.2246  R=0.2890  MAE=79.24  SAE=73.0523
#     fridge          F1=0.5627  P=0.3964  R=0.9692  MAE=49.71  SAE=38.0309
# ...

# %%
# !python test_pinn_lnn_ukdale_specific_splits_v3.py
# Out:
# Loading UKDALE v3 data from: /content/UKDALE-NILM/new_dataset
# train rows=14400  range=2014-09-11 00:00:00+00:00 -> 2014-09-11 23:59:54+00:00
# val   rows=14400  range=2014-11-09 00:00:00+00:00 -> 2014-11-09 23:59:54+00:00
# test  rows=14400  range=2014-12-19 00:00:00+00:00 -> 2014-12-19 23:59:54+00:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
# Using device: cuda
# seq2seq=True  lambda_phys=0.01  epsilon=50.0 W
# hidden=64  dt=0.1  BCE=disabled
# Train: (2861, 100, 1) -> (2861, 100, 4)
# Val:   (2861, 100, 1) -> (2861, 100, 4)
# Test:  (2861, 100, 1) -> (2861, 100, 4)
# Model parameters: 9,028
# Starting seq2seq PINN-LNN training...
#   Epoch   1/80  train=0.04196 (mse=0.02362 phys=1.835)  val=0.03448 (mse=0.00497 phys=2.951)  avgF1=0.3134  avgMAE=79.32  lr=1.00e-03
#     dish washer     F1=0.2049  P=0.1179  R=0.7810  MAE=100.74  SAE=78.2973
#     fridge          F1=0.5555  P=0.3926  R=0.9494  MAE=51.63  SAE=39.0861
# ...

# %%
# !python test_pinn_lnn_ukdale_specific_splits_v2.py
# Out:
# Loading UKDALE v2 data from: /content/UKDALE-NILM/new_dataset
# train rows=14400  range=2014-09-11 00:00:00+00:00 -> 2014-09-11 23:59:54+00:00
# val   rows=14400  range=2014-11-09 00:00:00+00:00 -> 2014-11-09 23:59:54+00:00
# test  rows=14400  range=2014-12-19 00:00:00+00:00 -> 2014-12-19 23:59:54+00:00
# Available columns: ['main', 'dish washer', 'fridge', 'microwave', 'washer dryer']
# Using device: cuda
# λ_phys=0.01  ε=50.0 W  hidden=64  dt=0.1
# Train: (2860, 100, 1) → (2860, 4)
# Val:   (2860, 100, 1) → (2860, 4)
# Test:  (2860, 100, 1) → (2860, 4)
# Model parameters: 9,028
# Starting PINN-LNN training (all appliances simultaneously)...
#   Epoch   1/80  train=0.05803 (mse=0.05803 phys=96.08603)  val=0.13998 (mse=0.01884 phys=12.11396)  avgF1=0.3199  avgMAE=86.93  lr=1.00e-03
#     dish washer     F1=0.2272  P=0.1317  R=0.8263  MAE=66.22  SAE=61.7498
#     fridge          F1=0.5635  P=0.3929  R=0.9964  MAE=45.06  SAE=18.9357
# ...

# %%
# !python fixed_pinn_lnn_energy_ukdale.py
# Out:
# Loading UKDALE CSV data ...
#   train :  14400 rows  2014-11-09 -> 2014-11-09
#   val   :  14400 rows  2014-12-07 -> 2014-12-07
#   test  :  14400 rows  2014-08-24 -> 2014-08-24
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Fixes applied: sigmoid heads, Seq2Seq, BiLNN, physics@all-t, Z-score, 8-ch features, BCEWithLogits, adaptive thresholds
#
#   Eval thresholds (W):        [used for metrics]
#   Appliance           Train      Val     Test
#   dishwasher           21.0     44.0     77.0
#   fridge               10.0     10.0     10.0
#   microwave            21.0     21.0     68.0
#   washing_machine      23.0     23.0     35.0
#   Event BCE thresholds (W):   [used for training targets]
#   dishwasher           21.0
#   fridge              104.0
#   microwave            21.0
#   washing_machine      23.0
#
# Creating sequences ...
# ...

# %%
# !python fixed_pinn_lnn_ukdale.py
# Out:
# Loading UKDALE CSV data ...
#   train :  14400 rows  2014-11-09 -> 2014-11-09
#   val   :  14400 rows  2014-12-07 -> 2014-12-07
#   test  :  14400 rows  2014-08-24 -> 2014-08-24
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Fixes applied: sigmoid heads, Seq2Seq, BiLNN, physics@all-t, Z-score, 8-ch features, BCEWithLogits, adaptive thresholds
#
#   Eval thresholds (W):        [used for metrics]
#   Appliance           Train      Val     Test
#   dishwasher           21.0     44.0     77.0
#   fridge               10.0     10.0     10.0
#   microwave            21.0     21.0     68.0
#   washing_machine      23.0     23.0     35.0
#   Event BCE thresholds (W):   [used for training targets]
#   dishwasher           21.0
#   fridge              104.0
#   microwave            21.0
#   washing_machine      23.0
#
# Creating sequences ...
# ...

# %%
# !python multiresolution_pinn_lnn_ukdale.py
# Out:
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
#   Fast branch RF: 15 steps  (90s  ~2 min)
#   Slow branch RF: 199 steps  (1194s  ~20 min)
#
# Loading data ...
#   train       :  14400 rows
#   validation  :  14400 rows
#   test        :  14400 rows
#
#   Adaptive ON/OFF thresholds (W):
#   Appliance                 Train      Val     Test
#   dishwasher                 21.0     44.0     77.0
#   fridge                    104.0    103.0    126.0
#   microwave                  21.0     21.0     68.0
#   washing_machine            23.0     23.0     35.0
#
# Computing features (median + EMA + delta + rolling stats) ...
#
# Train : (1411, 299, 12) -> (1411, 299, 4)  (421,889 predictions)
# Val   : (1411, 299, 12) -> (1411, 299, 4)
# Test  : (48, 299, 12) -> (48, 299, 4)  [non-overlapping]
#
#   Agg Z-score:  mean=455.3 W  std=655.2 W
#
#   Event pos_weight per appliance (clamped to [1, 50]):
#     dishwasher              on=  6.8%  pos_weight=  13.8
# ...

# %%
# !python hf_pinn_lnn_ukdale.py
# Out:
# Device: cuda  |  WIN=299  hidden=64  dt=0.1  lambda_phys=0.01  epsilon=50.0 W
#
# Loading HF CSV data...
#   train       :  14400 rows | ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#   validation  :  14400 rows | ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#   test        :  14400 rows | ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Train : (7051, 299, 4) -> (7051, 4)
# Val   : (7051, 299, 4) -> (7051, 4)
# Test  : (7051, 299, 4) -> (7051, 4)
# Model parameters: 56,260
#
# Starting HF-PINN-LNN training (all appliances simultaneously)...
#   Epoch   1/80  train=0.01073 (mse=0.01073 phys=47.88296)  val=0.24995 (mse=0.00689 phys=24.30594)  avgF1=0.2870  avgMAE=77.05  lr=1.00e-03
#     dishwasher              F1=0.1147  P=0.0617  R=0.8050  MAE=95.05  SAE=72.6124
#     fridge                  F1=0.6163  P=0.4458  R=0.9983  MAE=40.95  SAE=30.3221
# ...

# %%
# !python hf_seq2seq_pinn_lnn_ukdale.py
# Out:
# Device: cuda  |  WIN=299  hidden=64  dt=0.1  lambda_phys=0.01  epsilon=50.0 W
#
# Loading HF CSV data...
#   train       :  14400 rows
#   validation  :  14400 rows
#   test        :  14400 rows
#
# Train : (1411, 299, 8) -> (1411, 299, 4)  (421,889 total predictions)
# Val   : (1411, 299, 8) -> (1411, 299, 4)  (421,889 total predictions)
# Test  : (48, 299, 8) -> (48, 299, 4)  [non-overlapping, reconstructed]
# Model parameters: 91,652
#
# Starting HF Seq2Seq PINN-LNN training (4 appliances)...
#   Epoch   1/80  train=0.04195 (mse=0.04195 phys=152.03985)  val=0.16669 (mse=0.00853 phys=15.81610)  avgF1=0.2482  avgMAE=106.66  lr=1.00e-03
#     dishwasher              F1=0.2264  P=0.1505  R=0.4569  MAE=86.03  SAE=72.3342
#     fridge                  F1=0.5412  P=0.4031  R=0.8233  MAE=53.46  SAE=44.6948
#     microwave               F1=0.1019  P=0.0542  R=0.8532  MAE=53.24  SAE=40.7519
#     washing_machine         F1=0.1233  P=0.0657  R=1.0000  MAE=233.90  SAE=216.7517
# ...
