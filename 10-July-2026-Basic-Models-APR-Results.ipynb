# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/10-July-2026-Basic-Models-APR-Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python APR-new-scripts/test_gru_apr_new_house1_dataset.py
# Out:
# Testing GRU on APR-new-House1-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House1-dataset
#   Train: 2014-09-08 00:00:00+00:00 to 2014-10-07 23:59:54+00:00  (432,000 rows)
#   Val: 2014-10-08 00:00:00+00:00 to 2014-10-14 23:59:54+00:00  (100,800 rows)
#   Test: 2014-10-15 00:00:00+00:00 to 2014-10-21 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing GRU on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting GRU training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:04<00:00, 582.28it/s, loss=0.000115]
# Epoch 1/80, Train Loss: 0.004435, Val Loss: 0.004568, Val MAE: 54.73, Val SAE: 50.52, Val F1: 0.0812, Val Precision: 0.0455, Val Recall: 0.3776
# ...

# %%
# !python APR-new-scripts/test_lnn_apr_new_house1_dataset.py
# Out:
# Testing LiquidNetworkModel on APR-new-House1-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House1-dataset
#   Train: 2014-09-08 00:00:00+00:00 to 2014-10-07 23:59:54+00:00  (432,000 rows)
#   Val: 2014-10-08 00:00:00+00:00 to 2014-10-14 23:59:54+00:00  (100,800 rows)
#   Test: 2014-10-15 00:00:00+00:00 to 2014-10-21 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing LiquidNetworkModel on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting LiquidNetworkModel training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:51<00:00, 52.10it/s, loss=0.00183]
# Epoch 1/80, Train Loss: 0.004613, Val Loss: 0.004729, Val MAE: 75.13, Val SAE: 65.07, Val F1: 0.0952, Val Precision: 0.0550, Val Recall: 0.3569
# ...

# %%
# !python APR-new-scripts/test_lstm_apr_new_house1_dataset.py
# Out:
# Testing LSTM on APR-new-House1-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House1-dataset
#   Train: 2014-09-08 00:00:00+00:00 to 2014-10-07 23:59:54+00:00  (432,000 rows)
#   Val: 2014-10-08 00:00:00+00:00 to 2014-10-14 23:59:54+00:00  (100,800 rows)
#   Test: 2014-10-15 00:00:00+00:00 to 2014-10-21 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing LSTM on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting LSTM training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:07<00:00, 346.15it/s, loss=8.5e-5]
# Epoch 1/80, Train Loss: 0.004732, Val Loss: 0.004893, Val MAE: 30.12, Val SAE: 28.24, Val F1: 0.1032, Val Precision: 0.0650, Val Recall: 0.2500
# ...

# %%
# !python APR-new-scripts/test_resnet_apr_new_house1_dataset.py
# Out:
# Testing ResNet on APR-new-House1-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House1-dataset
#   Train: 2014-09-08 00:00:00+00:00 to 2014-10-07 23:59:54+00:00  (432,000 rows)
#   Val: 2014-10-08 00:00:00+00:00 to 2014-10-14 23:59:54+00:00  (100,800 rows)
#   Test: 2014-10-15 00:00:00+00:00 to 2014-10-21 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing ResNet on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting ResNet training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:08<00:00, 320.26it/s, loss=0.00195]
# Epoch 1/80, Train Loss: 0.006579, Val Loss: 0.011781, Val MAE: 94.57, Val SAE: 76.47, Val F1: 0.0532, Val Precision: 0.0275, Val Recall: 0.8172
# ...

# %%
# !python APR-new-scripts/test_tcn_apr_new_house1_dataset.py
# Out:
# Testing TCN on APR-new-House1-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House1-dataset
#   Train: 2014-09-08 00:00:00+00:00 to 2014-10-07 23:59:54+00:00  (432,000 rows)
#   Val: 2014-10-08 00:00:00+00:00 to 2014-10-14 23:59:54+00:00  (100,800 rows)
#   Test: 2014-10-15 00:00:00+00:00 to 2014-10-21 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing TCN on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting TCN training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:03<00:00, 856.69it/s, loss=0.00583]
# Epoch 1/80, Train Loss: 0.002496, Val Loss: 0.002090, Val MAE: 30.49, Val SAE: 22.13, Val F1: 0.2495, Val Precision: 0.1934, Val Recall: 0.3517
# ...

# %%
# !python APR-new-scripts/test_transformer_apr_new_house1_dataset.py
# Out:
# Testing Transformer on APR-new-House1-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House1-dataset
#   Train: 2014-09-08 00:00:00+00:00 to 2014-10-07 23:59:54+00:00  (432,000 rows)
#   Val: 2014-10-08 00:00:00+00:00 to 2014-10-14 23:59:54+00:00  (100,800 rows)
#   Test: 2014-10-15 00:00:00+00:00 to 2014-10-21 23:59:54+00:00  (100,800 rows)
#
# ...
# Testing Transformer on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting Transformer training for dishwasher...
# Epoch 1/80: 100% 2700/2700 [00:08<00:00, 305.67it/s, loss=0.000146]
# Epoch 1/80, Train Loss: 0.012370, Val Loss: 0.003748, Val MAE: 64.67, Val SAE: 63.68, Val F1: 0.0561, Val Precision: 0.0289, Val Recall: 1.0000
# ...

# %%
# !python APR-new-scripts/test_pinn_basic_lnn_dataset_dir.py
# Out:
# Loading data from: /content/UKDALE-NILM/dataset
#   Train: 2014-11-09 00:00:00+00:00 to 2014-11-09 23:59:54+00:00  (14,400 rows)  cols=['main', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#   Val: 2014-12-07 00:00:00+00:00 to 2014-12-07 23:59:54+00:00  (14,400 rows)  cols=['main', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#   Test: 2014-08-24 00:00:00+00:00 to 2014-08-24 23:59:54+00:00  (14,400 rows)  cols=['main', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
# Using device: cuda
# lambda_phys=0.01  epsilon=50.0 W  hidden=64  dt=0.1
# Thresholds: {'dishwasher': 10.0, 'fridge': 10.0, 'microwave': 30.0, 'washing_machine': 18.0}
# Train: (2860, 100, 1) -> (2860, 4)
# Val:   (2860, 100, 1) -> (2860, 4)
# Test:  (2860, 100, 1) -> (2860, 4)
# Model parameters: 4,804
# Starting PINN-BasicLNN training (all appliances simultaneously)...
# ...

# %%
# !python APR-new-scripts/test_pinn_lnn_apr_dataset.py
# Out:
# Loading data from: /content/UKDALE-NILM/APR-dataset
#   Train: 2014-11-09 00:00:00+00:00 to 2014-11-09 23:59:54+00:00  (14,400 rows)
#   Val: 2014-12-07 00:00:00+00:00 to 2014-12-07 23:59:54+00:00  (14,400 rows)
#   Test: 2014-12-19 00:00:00+00:00 to 2014-12-19 23:59:54+00:00  (14,400 rows)
# Using device: cuda
# lambda_phys=0.01  epsilon=50.0 W  hidden=64  dt=0.1
# Thresholds: {'dishwasher': 10.0, 'fridge': 10.0, 'microwave': 10.0, 'washing_machine': 10.0}
# Train: (2860, 100, 1) -> (2860, 4)
# Val:   (2860, 100, 1) -> (2860, 4)
# Test:  (2860, 100, 1) -> (2860, 4)
# Model parameters: 9,028
# Starting PINN-LNN training (all appliances simultaneously)...
#   Epoch   1/80  train=0.02523 (mse=0.02523 phys=117.67313)  val=0.11975 (mse=0.01233 phys=10.74155)  avgF1=0.2473  avgMAE=54.70  lr=1.00e-03
#     dishwasher            F1=0.1433  P=0.0772  R=1.0000  MAE=76.08  SAE=60.6509
#     fridge                F1=0.5908  P=0.4192  R=1.0000  MAE=48.05  SAE=27.6205
# ...
