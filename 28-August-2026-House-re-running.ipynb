# %% [markdown]
# <a href="https://colab.research.google.com/github/Ken89MathCompSci/UKDALE-NILM/blob/master/28-August-2026-House-re-running.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/UKDALE-NILM
# Out:
# /content/UKDALE-NILM

# %%
# %pwd
# Out:
# '/content/UKDALE-NILM'

# %%
# !python APR-new-scripts/test_transformer_apr_new_house1_dataset_v2.py
# Out:
# Testing Gated Transformer v2 on APR-new-House1-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House1-dataset
#   Train: 2014-09-08 00:00:00+00:00 to 2014-10-07 23:59:54+00:00  (432,000 rows)
#   Val: 2014-10-08 00:00:00+00:00 to 2014-10-14 23:59:54+00:00  (100,800 rows)
#   Test: 2014-10-15 00:00:00+00:00 to 2014-10-21 23:59:54+00:00  (100,800 rows)
#
#   Adaptive thresholds (train-locked, replaces v1's flat 10W):
#     dishwasher       21.0W
#     fridge           10.0W
#     microwave        21.0W
#     washing_machine  23.0W
#
# ...
# Testing Gated Transformer on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=21.0W)
#   Gate target: on=2.9%  pos_weight=33.9  thr_scaled=0.0075
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting Gated Transformer training for dishwasher...
# ...

# %%
# !python  APR-new-scripts/combined_pinn_lnn_apr_new_house1_dataset.py # latest
# Out:
# Loading APR-new-House1-dataset CSV data from '/content/UKDALE-NILM/APR-new-scripts/../APR-new-House1-dataset' ...
#   train : 432,000 rows  2014-09-08 -> 2014-10-07
#   val   : 100,800 rows  2014-10-08 -> 2014-10-14
#   test  : 100,800 rows  2014-10-15 -> 2014-10-21
#   Columns: ['aggregate', 'dishwasher', 'fridge', 'microwave', 'washing_machine']
#
# Device: cuda  |  WIN=299  hidden=64  dt=0.1
# Model: CombinedPINNAdvancedLNN  (gated power = gate x power)
#
#   Eval thresholds (W):
#   Appliance           Train      Val     Test
#   dishwasher           21.0     21.0     21.0
#   fridge               10.0     10.0     10.0
#   microwave            21.0     21.0     21.0
#   washing_machine      23.0     23.0     23.0
#
# Creating sequences ...
#   Train : (43171, 299, 8) -> (43171, 299, 4)  (12,908,129 predictions)
#   Val   : (10051, 299, 8) -> (10051, 299, 4)
#   Test  : (337, 299, 8) -> (337, 299, 4)  [non-overlapping]
#
#   Agg Z-score: mean=404.1 W  std=505.1 W
#
# ...

# %%
# !python APR-new-scripts/test_resnet_apr_new_house1_dataset_v2.py
# Out:
# Testing Gated ResNet v2 on APR-new-House1-dataset...
# Loading data from: /content/UKDALE-NILM/APR-new-House1-dataset
#   Train: 2014-09-08 00:00:00+00:00 to 2014-10-07 23:59:54+00:00  (432,000 rows)
#   Val: 2014-10-08 00:00:00+00:00 to 2014-10-14 23:59:54+00:00  (100,800 rows)
#   Test: 2014-10-15 00:00:00+00:00 to 2014-10-21 23:59:54+00:00  (100,800 rows)
#
#   Adaptive thresholds (train-locked, replaces v1's flat 10W):
#     dishwasher       21.0W
#     fridge           10.0W
#     microwave        21.0W
#     washing_machine  23.0W
#
# ...
# Testing Gated ResNet on dishwasher
# ...
#
# Using device: cuda
# Creating sequences for dishwasher...  (threshold=21.0W)
#   Gate target: on=2.9%  pos_weight=33.9  thr_scaled=0.0075
# Training sequences:   (86380, 100, 1) -> (86380, 1)
# Validation sequences: (20140, 100, 1) -> (20140, 1)
# Test sequences:       (20140, 100, 1) -> (20140, 1)
# Starting Gated ResNet training for dishwasher...
# ...

# %%
# !python APR-new-scripts/nilm_sfra_svm_house1.py  --backend svc
# Out:
# Loading APR-new-House1-dataset CSV data from '/content/UKDALE-NILM/APR-new-scripts/../APR-new-House1-dataset' ...
#   train : 432,000 rows  2014-09-08 -> 2014-10-07
#   val   : 100,800 rows  2014-10-08 -> 2014-10-14
#   test  : 100,800 rows  2014-10-15 -> 2014-10-21
#
# Adaptive thresholds (train-locked): dishwasher=21.0W, fridge=10.0W, microwave=21.0W, washing_machine=23.0W
# Window: 6.0 min (60 steps)  train_stride=3.0 min  on_fraction>=5%
#
# Building windows ...
#   Train windows: (14399, 31)  Val windows: (1680, 31)  Test windows: (1680, 31)
#   train ON-fraction per appliance: dishwasher=3.3%, fridge=61.2%, microwave=4.8%, washing_machine=7.6%
#   val   ON-fraction per appliance: dishwasher=3.5%, fridge=58.7%, microwave=4.9%, washing_machine=7.9%
#   test  ON-fraction per appliance: dishwasher=2.2%, fridge=60.8%, microwave=4.8%, washing_machine=9.3%
#
#   Subsampled train windows to 2,000 (random, seed=0) for svc training tractability.
# ...
